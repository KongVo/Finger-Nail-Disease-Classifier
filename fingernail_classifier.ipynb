# %% [markdown]
# #Creating our own dataset using Google Images
# In this notebook we are creating our own dataset of teddy bear, black bear and grizzly bear and try to classify between them.We are going to use following javascript code to download the images from Google Images.
#
# **javascript code**:
#
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
#
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));

# %%
#importing the required packages
from fastai.vision import *
from fastai.metrics import error_rate

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
#get the current working directory
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\KV\Desktop\bear-classifier-master

# %%
#deleting corrupted images
classes = ['Black_Nails','Blue_Nails','Green_Nails','Healthy_Nails','White_Nails','Yellow_Nails']
           

for c in classes:
  print(c)
  verify_images(cwd, delete = True, max_size = 500)

# %%
#view data
data = ImageDataBunch.from_folder(cwd, train='.', valid_pct = 0.2, seed=66,
                                  ds_tfms = get_transforms(), size = 224).normalize(imagenet_stats)
data.show_batch(rows = 5, figsize = (10,10))

# %%
print(data.classes)
print(len(data.train_ds))
print(len(data.valid_ds))
# Out:
# ['Black_Nails', 'Blue_Nails', 'Green_Nails', 'Healthy_Nails', 'White_Nails', 'Yellow_Nails', 'bear-classifier-master']
# 1700
# 424

# %% [markdown]
# #Training

# %%
learn = cnn_learner(data, models.resnet34, metrics = error_rate)

# %%
learn.fit_one_cycle(12)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.215912</td>
#       <td>0.716873</td>
#       <td>0.226415</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.302541</td>
#       <td>0.249871</td>
#       <td>0.058962</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.834130</td>
#       <td>0.223769</td>
#       <td>0.058962</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.615292</td>
#       <td>0.176290</td>
#       <td>0.044811</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.465265</td>
#       <td>0.178645</td>
#       <td>0.051887</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.379476</td>
#       <td>0.181467</td>
#       <td>0.035377</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.315027</td>
#       <td>0.156924</td>
#       <td>0.040094</td>
#       <td>01:16</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.262351</td>
#       <td>0.154977</td>
#       <td>0.035377</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.228894</td>
#       <td>0.142128</td>
#       <td>0.033019</td>
#       <td>01:16</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.204177</td>
#       <td>0.126195</td>
#       <td>0.030660</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.189480</td>
#       <td>0.134239</td>
#       <td>0.035377</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.169970</td>
#       <td>0.133179</td>
#       <td>0.035377</td>
#       <td>01:18</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(3,max_lr=slice(3e-5,3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.182599</td>
#       <td>0.125255</td>
#       <td>0.025943</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.188963</td>
#       <td>0.122603</td>
#       <td>0.028302</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.162375</td>
#       <td>0.097981</td>
#       <td>0.021226</td>
#       <td>01:18</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# This doesn't help much so we use the stage-1 training.

# %%
learn.save('stage-2')

# %% [markdown]
# #Interpretation

# %%
learn.load('stage-1');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(k = 4, heatmap=False)

# %% [markdown]
# #Prediction

# %%
defaults.device = torch.device('cuda')

# %%
learn.export()

# %%
#example image
img = open_image(cwd+'/aug_91.jpg')
img
# Out:
# Image (3, 256, 341)

# %%
learn = load_learner(cwd)

# %%
pred,idx,outputs = learn.predict(img)
print('Predicted class: ',pred)
# Out:
# Predicted class:  Black_Nails
